# %% [markdown]
# # An introduction to the Google trends API
#
# Package info: pytrends 4.8.0

# %%
from src.functions import interest_over_time

# %%
print(interest_over_time(
    search_term='bezos',
    start_time='2016-12-14',
    end_time='2017-01-25'))
# Out:
#             bezos  isPartial
# date
# 2016-12-14     39      False
# 2016-12-15     50      False
# 2016-12-16     26      False
# 2016-12-17     17      False
# 2016-12-18     15      False
# 2016-12-19     26      False
# 2016-12-20     15      False
# 2016-12-21     19      False
# 2016-12-22     18      False
# 2016-12-23     17      False
# 2016-12-24     15      False
# 2016-12-25      9      False
# 2016-12-26     17      False
# 2016-12-27     18      False
# 2016-12-28     18      False
# 2016-12-29     28      False
# 2016-12-30     15      False
# 2016-12-31     12      False
# 2017-01-01     16      False
# 2017-01-02     18      False
# 2017-01-03     19      False
# 2017-01-04     18      False
# 2017-01-05     22      False
# 2017-01-06     18      False
# 2017-01-07     13      False
# 2017-01-08     16      False
# 2017-01-09     48      False
# 2017-01-10     31      False
# 2017-01-11     18      False
# 2017-01-12     49      False
# 2017-01-13     65      False
# 2017-01-14     27      False
# 2017-01-15     23      False
# 2017-01-16    100      False
# 2017-01-17     68      False
# 2017-01-18     35      False
# 2017-01-19     23      False
# 2017-01-20     23      False
# 2017-01-21     18      False
# 2017-01-22     25      False
# 2017-01-23     21      False
# 2017-01-24     21      False
# 2017-01-25     24      False

# %%
# Interest per region

#import the libraries
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

#provide your search terms
kw_list=['Ukraine']

#search interest per region
#run model for keywords (can also be competitors)
pytrend.build_payload(kw_list, timeframe='today 1-m')

# Interest by Region
regiondf = pytrend.interest_by_region()
#looking at rows where all values are not equal to 0
regiondf = regiondf[(regiondf != 0).all(1)]

#drop all rows that have null values in all columns
regiondf.dropna(how='all',axis=0, inplace=True)

#visualise
regiondf.plot(figsize=(20, 12), y=kw_list, kind ='bar')
# Out:
# <AxesSubplot:xlabel='geoName'>

# %%
#historical interest
historicaldf = pytrend.get_historical_interest(kw_list, year_start=2020, month_start=10, day_start=1, hour_start=0, year_end=2021, month_end=10, day_end=1, hour_end=0, cat=0, geo='', gprop='', sleep=0)

#visualise
#plot a timeseries chart
historicaldf.plot(figsize=(20, 12))

#plot seperate graphs, using theprovided keywords
historicaldf.plot(subplots=True, figsize=(20, 12))
# Out:
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# The request failed: Google returned a response with code 500.
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# The request failed: Google returned a response with code 500.
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# The request failed: Google returned a response with code 500.
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# The request failed: Google returned a response with code 500.
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# The request failed: Google returned a response with code 500.
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# The request failed: Google returned a response with code 500.
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:589: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# /Users/soeren/opt/anaconda3/envs/googletrends/lib/python3.9/site-packages/pytrends/request.py:611: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(week_df)
# array([<AxesSubplot:xlabel='date'>], dtype=object)
